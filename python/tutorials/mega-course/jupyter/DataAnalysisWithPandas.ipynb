# %%
import pandas as pd
import os
#os.listdir()

# %%
df = pd.read_csv("supermarkets-no-headers.txt", header = None)
df
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df_json = pd.read_json("supermarkets.json")
df_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.columns = ["ID", "Address", "City", "Zip", "Country", "Name", "Population"]

# %%
df.set_index("ID", inplace=True)
df
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Population
# ID
# 1            8
# 2           15
# 3           25
# 4           10
# 5           12
# 6           20

# %%
df.loc[:3, "Zip":"Name"]
# Out:
#                  Zip Country         Name
# ID
# 1           CA 94114     USA      Madeira
# 2           CA 94119     USA  Bready Shop
# 3   California 94114     USA  Super River

# %%
df.loc[:2,"Country"]
# Out:
# ID
# 1    USA
# 2    USA
# Name: Country, dtype: object

# %%
list(df.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Population
# ID
# 1            8
# 2           15
# 3           25
# 4           10
# 5           12
# 6           20

# %%
df.iloc[1:3,2:4]
# Out:
#                  Zip Country
# ID
# 2           CA 94119     USA
# 3   California 94114     USA

# %%
df1 = df
df1
# Out:
#    ID          Address           City               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Population
# 0           8
# 1          15
# 2          25
# 3          10
# 4          12
# 5          20

# %%
df1.drop("Population",1)
# Out:
#    ID          Address           City               Zip Country         Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley

# %%
df1
# Out:
#    ID          Address           City               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Population
# 0           8
# 1          15
# 2          25
# 3          10
# 4          12
# 5          20

# %%
df.drop(df1.columns[0:3],1)
# Out:
#                 Zip Country         Name  Population
# 0          CA 94114     USA      Madeira           8
# 1          CA 94119     USA  Bready Shop          15
# 2  California 94114     USA  Super River          25
# 3          CA 94114     USA   Ben's Shop          10
# 4        California     USA      Sanchez          12
# 5          CA 94114     USA   Richvalley          20

# %%
df
# Out:
#    ID          Address           City               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Population
# 0           8
# 1          15
# 2          25
# 3          10
# 4          12
# 5          20

# %%
df.drop(df1.index[0:3],0)
# Out:
#             Address           City         Zip Country        Name  Population
# ID
# 4      3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop          10
# 5   1056 Sanchez St  San Francisco  California     USA     Sanchez          12
# 6   551 Alvarado St  San Francisco    CA 94114     USA  Richvalley          20

# %%
df.shape
# Out:
# (6, 7)

# %%
df["Continent"] = df.shape[0]*["North America"]

# %%
df
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Population      Continent
# ID
# 1            8  North America
# 2           15  North America
# 3           25  North America
# 4           10  North America
# 5           12  North America
# 6           20  North America

# %%
df.loc[1,"Continent"]
# Out:
# 'North America'

# %%
df["Continent"] = df["Continent"] + 2*df.loc[1,"Continent"]
df.loc[1, "Continent"]
# Out:
# 'North AmericaNorth AmericaNorth America'

# %%
df = df.drop("Continent", 1)

# %%
df
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Population
# ID
# 1            8
# 2           15
# 3           25
# 4           10
# 5           12
# 6           20

# %%
df_t = df.T
df_t
# Out:
# ID                      1               2                 3              4  \
# Address      3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City        San Francisco   San Francisco     San Francisco  San Francisco
# Zip              CA 94114        CA 94119  California 94114       CA 94114
# Country               USA             USA               USA            USA
# Name              Madeira     Bready Shop       Super River     Ben's Shop
# Population              8              15                25             10
#
# ID                        5                6
# Address     1056 Sanchez St  551 Alvarado St
# City          San Francisco    San Francisco
# Zip              California         CA 94114
# Country                 USA              USA
# Name                Sanchez       Richvalley
# Population               12               20

# %%
df_t.T
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Population
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1 = df["Continent"] = df.shape[0]*["USA, North America"]

# %%
df1
# Out:
# ['USA, North America',
#  'USA, North America',
#  'USA, North America',
#  'USA, North America',
#  'USA, North America',
#  'USA, North America']

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS

# %%
arcgis = ArcGIS()

# %%
address = arcgis.geocode("20 Commons Ln, Foster City, CA 94404")
print(address)
# Out:
# 20 Commons Ln, San Mateo, California, 94404

# %%
print(address.latitude, address.longitude)
# Out:
# 37.55654335775294 -122.27692473772287

# %%
df
# Out:
#                                               Address  Population   Latitude  \
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA           8  37.756450
# 2        735 Dolores St, San Francisco, CA 94119, USA          15  37.757796
# 3   332 Hill St, San Francisco, California 94114, USA          25  37.755648
# 4          3995 23rd St, San Francisco, CA 94114, USA          10  37.752991
# 5     1056 Sanchez St, San Francisco, California, USA          12  37.752129
# 6       551 Alvarado St, San Francisco, CA 94114, USA          20  37.753719
#
#       Logitude
# ID
# 1  -122.429364
# 2  -122.425597
# 3  -122.428803
# 4  -122.431702
# 5  -122.430028
# 6  -122.433240

# %%
df["Address"] = df["Street Address"] + ", " + df["City"] + ", " + df["Zip"] + ", " + df["Country"]

# %%
df
# Out:
#                                               Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114, USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California, USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#                  Zip Country         Name  Population           Continent  \
# ID
# 1           CA 94114     USA      Madeira           8  USA, North America
# 2           CA 94119     USA  Bready Shop          15  USA, North America
# 3   California 94114     USA  Super River          25  USA, North America
# 4           CA 94114     USA   Ben's Shop          10  USA, North America
# 5         California     USA      Sanchez          12  USA, North America
# ...

# %%
type(df["Address"])
# Out:
# pandas.core.series.Series

# %%
df["Coordinates"] = df["Address"].apply(arcgis.geocode)
df
# Out:
#                                               Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114, USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California, USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#                  Zip Country         Name  Population           Continent  \
# ID
# 1           CA 94114     USA      Madeira           8  USA, North America
# 2           CA 94119     USA  Bready Shop          15  USA, North America
# 3   California 94114     USA  Super River          25  USA, North America
# 4           CA 94114     USA   Ben's Shop          10  USA, North America
# 5         California     USA      Sanchez          12  USA, North America
# ...

# %%
df.Coordinates[1].latitude
# Out:
# 37.7564496899993

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x is not None else None)
df
# Out:
#                                               Address           City  \
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 2        735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 3   332 Hill St, San Francisco, California 94114, USA  San Francisco
# 4          3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 5     1056 Sanchez St, San Francisco, California, USA  San Francisco
# 6       551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#                  Zip Country         Name  Population           Continent  \
# ID
# 1           CA 94114     USA      Madeira           8  USA, North America
# 2           CA 94119     USA  Bready Shop          15  USA, North America
# 3   California 94114     USA  Super River          25  USA, North America
# 4           CA 94114     USA   Ben's Shop          10  USA, North America
# 5         California     USA      Sanchez          12  USA, North America
# ...

# %%
df["Logitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df.shape()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Coordinates'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-675d4c743dce> in <module>
# ...

# %%
df = df.drop("Coordinates", 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-7a443421eb4e> in <module>
# ----> 1 df = df.drop("Coordinates", 1)
#       2 df
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df
# Out:
#                                               Address  Population  \
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA           8
# 2        735 Dolores St, San Francisco, CA 94119, USA          15
# 3   332 Hill St, San Francisco, California 94114, USA          25
# 4          3995 23rd St, San Francisco, CA 94114, USA          10
# 5     1056 Sanchez St, San Francisco, California, USA          12
# 6       551 Alvarado St, San Francisco, CA 94114, USA          20
#
#              Continent   Street Address   Latitude    Logitude
# ID
# 1   USA, North America     3666 21st St  37.756450 -122.429364
# 2   USA, North America   735 Dolores St  37.757796 -122.425597
# 3   USA, North America      332 Hill St  37.755648 -122.428803
# 4   USA, North America     3995 23rd St  37.752991 -122.431702
# 5   USA, North America  1056 Sanchez St  37.752129 -122.430028
# 6   USA, North America  551 Alvarado St  37.753719 -122.433240

# %%
df = df.drop(df.columns[2:4],1)

# %%
df.to_csv("checking/supermarkets_modified.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-133-6faf56a51750> in <module>
# ----> 1 df.to_csv("checking/supermarkets_modified.csv")
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ...

# %%
df
# Out:
#                                               Address  Population   Latitude  \
# ID
# 1          3666 21st St, San Francisco, CA 94114, USA           8  37.756450
# 2        735 Dolores St, San Francisco, CA 94119, USA          15  37.757796
# 3   332 Hill St, San Francisco, California 94114, USA          25  37.755648
# 4          3995 23rd St, San Francisco, CA 94114, USA          10  37.752991
# 5     1056 Sanchez St, San Francisco, California, USA          12  37.752129
# 6       551 Alvarado St, San Francisco, CA 94114, USA          20  37.753719
#
#       Logitude
# ID
# 1  -122.429364
# 2  -122.425597
# 3  -122.428803
# 4  -122.431702
# 5  -122.430028
# 6  -122.433240
